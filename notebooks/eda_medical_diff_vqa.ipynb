# %% [markdown]
# ## Data Description
#
# ### mimic_all.csv
#
# This file includes the metadata from MIMIC-CXR and labels from MIMIC-CXR-JPG. The labels are for reference purposes only. The columns are:
# - _subject_id:_ subject id in MIMIC-CXR
# - _study_id:_ study_id in MIMIC-CXR
# - _labels:_ This section contains the labels that were extracted from MIMIC-CXR-JPG, but they are only for reference purposes.
#     - Atelectasis
#     - Cardiomegaly
#     - Consolidation
#     - Edema
#     - Enlarged Cardiomediastinum
#     - Fracture
#     - Lung Lesion
#     - Lung Opacity
#     - Pleural Effusion
#     - Pneumonia
#     - Pneumothorax
#     - Pleural Other
#     - Support Devices
#     - No Finding
# - _dicom_id:_ dicom_id in MIMIC-CXR
# - _view:_ "PA" or "AP" view of the image
# - _split:_ train/val/test split used in MIMIC-CXR-JPG. It is only for reference purposes.
# - _study_date:_
#     - StudyDate in MIMIC-CXR-JPG. Each patient was also assigned a date shift which mapped their first index admission year to a year between 2100 - 2200. This ensures anonymity of the data while preserving the relative chronology of patient information, which is crucial for appropriate processing of the data.
# - _study_order:_
#     - an integer that indicates the order number of a patient's entire visit history. Each patient may have multiple visits, but we select only two visits for pair comparison in order to create the final difference VQA dataset.
#
#
# ### mimic_pairs.csv
# This is the final generated question-answer pairs of the difference VQA dataset. The columns include the following:
# - study_id: main study_id in MIMIC-CXR.
# - subject_id: subject id in MIMIC-CXR.
# - ref_id: reference study_id in MIMIC-CXR.
# - question_type: abnormality/location/level/view/type/presence/difference.
# - question
# - answer
# - split: train/val/test split.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import os

data_path = '../data/medical-diff-vqa-1.0.1'
figures_path = '../figures'
vqa_file = 'mimic_pair_questions.csv'
metadata_file = 'mimic_all.csv'

# %%
vqa_df = pd.read_csv(os.path.join(data_path, vqa_file))
vqa_df.shape
# Out:
# (700703, 7)

# %%
vqa_df.head(30)
# Out:
#     study_id  subject_id    ref_id question_type  \
# 0   55088298    18936629  54989200   abnormality
# 1   55088298    18936629  54989200      presence
# 2   55088298    18936629  54989200      location
# 3   55088298    18936629  54989200         level
# 4   55088298    18936629  54989200    difference
# 5   51480826    18936629  50632107   abnormality
# 6   51480826    18936629  50632107      presence
# 7   51480826    18936629  50632107      location
# 8   51480826    18936629  50632107         level
# 9   50632107    18936629  51480826    difference
# 10  51268226    18936629  58729526   abnormality
# 11  51268226    18936629  58729526    difference
# 12  58729526    18936629  59181863   abnormality
# 13  58729526    18936629  59181863      presence
# 14  58729526    18936629  59181863          view
# 15  58729526    18936629  59181863      location
# 16  58729526    18936629  59181863         level
# 17  59181863    18936629  58729526    difference
# 18  56018384    18936629  56705148   abnormality
# 19  56018384    18936629  56705148      presence
# 20  56018384    18936629  56705148      location
# 21  56018384    18936629  56705148         level
# 22  56018384    18936629  56705148    difference
# 23  51132998    18936629  55754034   abnormality
# 24  51132998    18936629  55754034      presence
# 25  51132998    18936629  55754034      location
# 26  51132998    18936629  55754034         level
# 27  51132998    18936629  55754034          type
# 28  55754034    18936629  51132998    difference
# 29  50930709    18936629  50742417   abnormality
#
#                                              question  \
# 0    what abnormalities are seen in the soft tissues?
# 1                                     is there edema?
# 2   is the atelectasis located on the left side or...
# 3                     what level is the pneumothorax?
# 4   what has changed compared to the reference image?
# 5          what abnormalities are seen in this image?
# 6     is there pneumothorax in the right apical area?
# 7                          where is the pneumothorax?
# 8                 what level is the pleural effusion?
# 9   what has changed compared to the reference image?
# 10  is there evidence of any abnormalities in this...
# 11  what has changed compared to the reference image?
# 12         what abnormalities are seen in this image?
# 13   is there pleural effusion in the left lung area?
# 14                                   is this PA view?
# 15                   where is the pleural thickening?
# 16                what level is the pleural effusion?
# 17  what has changed compared to the reference image?
# 18         what abnormalities are seen in this image?
# 19   is there evidence of lung opacity in this image?
# 20                         where is the lung opacity?
# 21                what level is the pleural effusion?
# 22  what has changed compared to the reference image?
# 23         what abnormalities are seen in this image?
# 24     is there lung opacity in the left apical area?
# 25    where in the image is the lung opacity located?
# 26                           what level is the edema?
# 27                      what type is the atelectasis?
# 28  what has changed compared to the reference image?
# 29  is there evidence of any abnormalities in this...
#
#                                                answer  split
# 0                                         atelectasis  train
# 1                                                  no  train
# 2                                           left side  train
# 3                                             minimal  train
# 4   the main image has an additional finding of pn...  train
# 5   pleural effusion, pneumothorax, atelectasis, l...  train
# 6                                                  no  train
# 7                                    left apical area  train
# 8                                               small  train
# 9   the main image has additional findings of cons...  train
# 10                                                 no  train
# 11  the main image is missing the findings of lung...  train
# 12  lung opacity, consolidation, pleural effusion,...  train
# 13                                                yes  train
# 14                                                yes  train
# 15                                          left area  train
# 16                                              small  train
# 17  the main image has additional findings of edem...  train
# 18                     pleural effusion, lung opacity  train
# 19                                                yes  train
# 20                                     bibasilar area  train
# 21                                              small  train
# 22  the main image has additional findings of pleu...  train
# 23  pleural effusion, atelectasis, lung opacity, p...  train
# 24                                                 no  train
# 25                              the right middle lung  train
# 26                                               mild  train
# 27                                        compressive  train
# 28  the main image has an additional finding of ca...  train
# 29                                                yes  train

# %%
print(vqa_df.head(10).to_markdown())
# Out:
# |    |   study_id |   subject_id |   ref_id | question_type   | question                                                   | answer                                                                                                                                                                                                               | split   |
# |---:|-----------:|-------------:|---------:|:----------------|:-----------------------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:--------|
# |  0 |   55088298 |     18936629 | 54989200 | abnormality     | what abnormalities are seen in the soft tissues?           | atelectasis                                                                                                                                                                                                          | train   |
# |  1 |   55088298 |     18936629 | 54989200 | presence        | is there edema?                                            | no                                                                                                                                                                                                                   | train   |
# |  2 |   55088298 |     18936629 | 54989200 | location        | is the atelectasis located on the left side or right side? | left side                                                                                                                                                                                                            | train   |
# |  3 |   55088298 |     18936629 | 54989200 | level           | what level is the pneumothorax?                            | minimal                                                                                                                                                                                                              | train   |
# |  4 |   55088298 |     18936629 | 54989200 | difference      | what has changed compared to the reference image?          | the main image has an additional finding of pneumothorax than the reference image. the main image is missing the findings of fracture, lung opacity, and pleural effusion than the reference image.                  | train   |
# |  5 |   51480826 |     18936629 | 50632107 | abnormality     | what abnormalities are seen in this image?                 | pleural effusion, pneumothorax, atelectasis, lung opacity                                                                                                                                                            | train   |
# |  6 |   51480826 |     18936629 | 50632107 | presence        | is there pneumothorax in the right apical area?            | no                                                                                                                                                                                                                   | train   |
# |  7 |   51480826 |     18936629 | 50632107 | location        | where is the pneumothorax?                                 | left apical area                                                                                                                                                                                                     | train   |
# |  8 |   51480826 |     18936629 | 50632107 | level           | what level is the pleural effusion?                        | small                                                                                                                                                                                                                | train   |
# |  9 |   50632107 |     18936629 | 51480826 | difference      | what has changed compared to the reference image?          | the main image has additional findings of consolidation, and pneumonia than the reference image. the main image is missing the findings of pleural effusion, pneumothorax, and atelectasis than the reference image. | train   |

# %%
vqa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700703 entries, 0 to 700702
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   study_id       700703 non-null  int64
#  1   subject_id     700703 non-null  int64
#  2   ref_id         700703 non-null  int64
#  3   question_type  700703 non-null  object
#  4   question       700703 non-null  object
#  5   answer         700703 non-null  object
#  6   split          700703 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 37.4+ MB

# %%
plt.figure(figsize=(10,6))
sns.countplot(y='question_type', data=vqa_df, order=vqa_df['question_type'].value_counts().index, palette='Set2', hue='question_type')
plt.title('Distribution of Question Types')
plt.xlabel('Count')
plt.ylabel('Question Type')
plt.savefig(os.path.join(figures_path,'question_type_distribution.png'))
plt.tight_layout()
plt.show()

# %%
vqa_df['question_length'] = vqa_df['question'].str.len()
vqa_df['answer_length'] = vqa_df['answer'].str.len()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(vqa_df['question_length'], bins=30, kde=True)
plt.title('Distribution of Question Lengths')
plt.xlabel('Length of Question')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
sns.histplot(vqa_df['answer_length'], bins=30, kde=True)
plt.title('Distribution of Answer Lengths')
plt.xlabel('Length of Answer')
plt.ylabel('Frequency')

plt.tight_layout()
plt.savefig(os.path.join(figures_path,'qa_length_distribution.png'))
plt.show()

# %%
metadata_df = pd.read_csv(os.path.join(data_path, metadata_file))
metadata_df.shape
# Out:
# (227827, 21)

# %%
metadata_df.head(30)
# Out:
#     subject_id  study_id  Atelectasis  Cardiomegaly  Consolidation  Edema  \
# 0     10000032  50414267          NaN           NaN            NaN    NaN
# 1     10000032  53189527          NaN           NaN            NaN    NaN
# 2     10000032  53911762          NaN           NaN            NaN    NaN
# 3     10000032  56699142          NaN           NaN            NaN    NaN
# 4     10000764  57375967          NaN           NaN            1.0    NaN
# 5     10000898  50771383          NaN           NaN            NaN    NaN
# 6     10000898  54205396          NaN           NaN            NaN    NaN
# 7     10000935  50578979          NaN           NaN            NaN   -1.0
# 8     10000935  51178377          NaN           NaN            NaN    NaN
# 9     10000935  55697293          NaN           NaN            NaN    NaN
# 10    10000935  56164612          NaN           NaN            NaN    NaN
# 11    10000935  56522600          NaN           0.0            NaN    NaN
# 12    10000935  58219844          NaN           NaN            NaN   -1.0
# 13    10000980  50985099          NaN           NaN            NaN    0.0
# 14    10000980  51967283          NaN           NaN            NaN    NaN
# 15    10000980  54577367          NaN           NaN            NaN    NaN
# 16    10000980  54935705          NaN           NaN           -1.0    1.0
# 17    10000980  54980801          NaN           NaN            NaN    NaN
# 18    10000980  57861150          NaN           NaN            NaN    0.0
# 19    10000980  58206436          NaN           1.0            NaN    1.0
# 20    10000980  58636672          NaN           1.0            NaN    NaN
# 21    10000980  59988438          NaN           NaN            NaN    NaN
# 22    10001038  58224503          NaN           NaN            NaN    NaN
# 23    10001122  53447138          NaN           NaN            NaN    NaN
# 24    10001122  53957785          NaN           NaN            NaN    NaN
# 25    10001176  53186264         -1.0           NaN            NaN    NaN
# 26    10001176  54684191          NaN           NaN            NaN    1.0
# 27    10001217  52067803          1.0           NaN            NaN    NaN
# 28    10001217  58913004          NaN           1.0            NaN    NaN
# 29    10001401  50225296          NaN           0.0            NaN    0.0
#
#     Enlarged Cardiomediastinum  Fracture  Lung Lesion  Lung Opacity  ...  \
# 0                          NaN       NaN          NaN           NaN  ...
# 1                          NaN       NaN          NaN           NaN  ...
# 2                          NaN       NaN          NaN           NaN  ...
# 3                          NaN       NaN          NaN           NaN  ...
# 4                          NaN       NaN          NaN           NaN  ...
# 5                          NaN       NaN          NaN           NaN  ...
# 6                          NaN       NaN          NaN           NaN  ...
# 7                          NaN       NaN          NaN          -1.0  ...
# 8                          NaN       NaN          NaN           1.0  ...
# 9                          NaN       NaN          NaN           NaN  ...
# 10                         NaN       NaN          1.0           1.0  ...
# 11                         NaN       1.0          NaN           NaN  ...
# 12                         NaN       NaN          NaN           NaN  ...
# 13                         NaN       NaN          NaN           NaN  ...
# 14                         NaN       NaN          1.0           NaN  ...
# 15                         NaN       NaN          NaN           NaN  ...
# 16                         NaN       NaN          NaN           NaN  ...
# 17                         NaN       NaN          NaN           NaN  ...
# 18                         NaN       NaN          NaN           NaN  ...
# 19                         NaN       NaN          NaN           NaN  ...
# 20                         NaN       NaN          NaN           NaN  ...
# 21                         NaN       NaN          NaN           NaN  ...
# 22                         NaN       NaN          NaN           NaN  ...
# 23                         NaN       NaN          NaN           NaN  ...
# 24                         NaN       NaN          NaN           NaN  ...
# 25                         NaN       NaN          NaN           1.0  ...
# 26                         NaN       NaN          NaN           NaN  ...
# 27                         NaN       NaN          NaN           NaN  ...
# 28                         NaN       NaN          NaN           NaN  ...
# 29                         NaN       NaN          NaN           NaN  ...
#
#     Pleural Effusion  Pleural Other  Pneumonia  Pneumothorax  Support Devices  \
# 0                NaN            NaN        NaN           NaN              NaN
# 1                NaN            NaN        NaN           NaN              NaN
# 2                NaN            NaN        NaN           NaN              NaN
# 3                NaN            NaN        NaN           NaN              NaN
# 4                NaN            NaN       -1.0           NaN              NaN
# 5                NaN            NaN        NaN           NaN              NaN
# 6                NaN            NaN        NaN           NaN              NaN
# 7                1.0            NaN        1.0           NaN              NaN
# 8                NaN            NaN       -1.0           NaN              NaN
# 9                NaN            NaN        NaN           NaN              NaN
# 10               NaN            NaN        NaN           NaN              NaN
# 11               NaN            NaN        NaN           NaN              NaN
# 12               NaN            NaN        NaN           NaN              NaN
# 13               0.0            NaN        0.0           NaN              NaN
# 14               NaN            NaN        1.0           NaN              NaN
# 15               NaN            NaN        0.0           NaN              NaN
# 16               NaN            NaN       -1.0           NaN              NaN
# 17               NaN            NaN        NaN           NaN              NaN
# 18               1.0            NaN        NaN           NaN              NaN
# 19               1.0            NaN        NaN           NaN              NaN
# 20               1.0            NaN        0.0           NaN              NaN
# 21               1.0            NaN        NaN           NaN              NaN
# 22               NaN            NaN        NaN           NaN              NaN
# 23               0.0            NaN        0.0           NaN              NaN
# 24               NaN            NaN        NaN           NaN              NaN
# 25               NaN            NaN        0.0           NaN              NaN
# 26               NaN            NaN        NaN           NaN              NaN
# 27               NaN            NaN        NaN           NaN              NaN
# 28               NaN            NaN        NaN           1.0              1.0
# 29               0.0            NaN        0.0           NaN              1.0
#
#                                         dicom_id              view  split  \
# 0   02aa804e-bde0afdd-112c0b34-7bc16630-4e384014  postero-anterior  train
# 1   2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab  postero-anterior  train
# 2   68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714  antero-posterior  train
# 3   ea030e7a-2e3b1346-bc518786-7a8fd698-f673b44c  antero-posterior  train
# 4   096052b7-d256dc40-453a102b-fa7d01c6-1b22c6b4  antero-posterior  train
# 5   2a280266-c8bae121-54d75383-cac046f4-ca37aa16  postero-anterior  train
# 6   b75df1bd-0f22d631-52d73526-2ae7b85a-d843b39d  postero-anterior  train
# 7   d0b71acc-b5a62046-bbb5f6b8-7b173b85-65cdf738  antero-posterior  train
# 8   9b314ad7-fbcb0422-6db62dfc-732858d0-a5527d8b  antero-posterior  train
# 9   c50494f1-90e2bff5-e9189550-1a4562fd-6ab5204c  postero-anterior  train
# 10  8e3f2822-0c1d4b71-2a265bbf-5b96e531-ccf5fa30  antero-posterior  train
# 11  f1adcae3-2921c0a8-5d9652f9-4191ecd7-f2a96f35  postero-anterior  train
# 12  88498b37-c21dc7ba-bc202800-b517a62d-f7ac5bcf  antero-posterior  train
# 13  6ad03ed1-97ee17ee-9cf8b320-f7011003-cd93b42d  postero-anterior  train
# 14  943486a3-b3fa9ff7-50f5a769-7a62fcbb-f39b6da4  antero-posterior  train
# 15  cfb03587-782edf6c-1bf392e1-98196cd5-365d69e8  antero-posterior  train
# 16  6ad819bb-bae74eb9-7b663e90-b8deabd7-57f8054a  postero-anterior  train
# 17  a75a1fbe-802065ad-717eb7c1-e2ce3552-646276a6  antero-posterior  train
# 18  5aa15ba6-55f5e96e-39cea686-7c3b28b2-b8c97a88  postero-anterior  train
# 19  54affd39-8bf24209-232bac8a-df6c277a-398ee8a5  antero-posterior  train
# 20  c7526473-7b7214ee-a5d58d12-29d1f67f-9f4edf00  postero-anterior  train
# 21  925b9496-a956d7b2-05185e52-bb33313b-c06ee522  postero-anterior  train
# 22  28fad2ac-d6001216-b4f72c5b-2d4d452e-17b6c9a5  postero-anterior  train
# 23  8039752c-2ea661b7-16f1eafe-055b7e7b-dbd4cdd1               NaN  train
# 24  07b9ddda-9a4a1e1a-4495463d-4c77d947-ed368713  antero-posterior  train
# 25  1fe73f8e-036bd24e-4578c891-33c1746e-864884a7  postero-anterior  train
# 26  3b8b1b7d-054490d5-385641e7-ff43d2c8-9505f058  postero-anterior  train
# 27  a917c883-720a5bbf-02c84fc6-98ad00ac-c562ff80  postero-anterior  train
# 28  5e54fc9c-37c49834-9ac3b915-55811712-9d959d26  antero-posterior  train
# 29  0009a9fb-eb905e90-824cad7c-16d40468-007f0038  antero-posterior  train
#
#    study_date  study_order
# 0    21800506          1.0
# 1    21800626          2.0
# 2    21800723          3.0
# 3    21800805          4.0
# 4    21321015          1.0
# 5    21880312          2.0
# 6    21880113          1.0
# 7    21871016          6.0
# 8    21870823          4.0
# 9    21870226          2.0
# 10   21870711          3.0
# 11   21860730          1.0
# 12   21871010          5.0
# 13   21910917          9.0
# 14   21890627          2.0
# 15   21910613          7.0
# 16   21910716          8.0
# 17   21901106          3.0
# 18   21910530          6.0
# 19   21910523          5.0
# 20   21910522          4.0
# 21   21880103          1.0
# 22   21490807          1.0
# 23   21431210          2.0
# 24   21420408          1.0
# 25   21861128          1.0
# 26   21861201          2.0
# 27   21571118          1.0
# 28   21571218          2.0
# 29   21310610          1.0
#
# [30 rows x 21 columns]

# %%
print(metadata_df.head(10).to_markdown())
# Out:
# |    |   subject_id |   study_id |   Atelectasis |   Cardiomegaly |   Consolidation |   Edema |   Enlarged Cardiomediastinum |   Fracture |   Lung Lesion |   Lung Opacity |   No Finding |   Pleural Effusion |   Pleural Other |   Pneumonia |   Pneumothorax |   Support Devices | dicom_id                                     | view             | split   |   study_date |   study_order |
# |---:|-------------:|-----------:|--------------:|---------------:|----------------:|--------:|-----------------------------:|-----------:|--------------:|---------------:|-------------:|-------------------:|----------------:|------------:|---------------:|------------------:|:---------------------------------------------|:-----------------|:--------|-------------:|--------------:|
# |  0 |     10000032 |   50414267 |           nan |            nan |             nan |     nan |                          nan |        nan |           nan |            nan |            1 |                nan |             nan |         nan |            nan |               nan | 02aa804e-bde0afdd-112c0b34-7bc16630-4e384014 | postero-anterior | train   |     21800506 |             1 |
# |  1 |     10000032 |   53189527 |           nan |            nan |             nan |     nan |                          nan |        nan |           nan |            nan |            1 |                nan |             nan |         nan |            nan |               nan | 2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab | postero-anterior | train   |     21800626 |             2 |
# |  2 |     10000032 |   53911762 |           nan |            nan |             nan |     nan |                          nan |        nan |           nan |            nan |            1 |                nan |             nan |         nan |            nan |               nan | 68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714 | antero-posterior | train   |     21800723 |             3 |
# |  3 |     10000032 |   56699142 |           nan |            nan |             nan |     nan |                          nan |        nan |           nan |            nan |            1 |                nan |             nan |         nan |            nan |               nan | ea030e7a-2e3b1346-bc518786-7a8fd698-f673b44c | antero-posterior | train   |     21800805 |             4 |
# |  4 |     10000764 |   57375967 |           nan |            nan |               1 |     nan |                          nan |        nan |           nan |            nan |          nan |                nan |             nan |          -1 |            nan |               nan | 096052b7-d256dc40-453a102b-fa7d01c6-1b22c6b4 | antero-posterior | train   |     21321015 |             1 |
# |  5 |     10000898 |   50771383 |           nan |            nan |             nan |     nan |                          nan |        nan |           nan |            nan |            1 |                nan |             nan |         nan |            nan |               nan | 2a280266-c8bae121-54d75383-cac046f4-ca37aa16 | postero-anterior | train   |     21880312 |             2 |
# |  6 |     10000898 |   54205396 |           nan |            nan |             nan |     nan |                          nan |        nan |           nan |            nan |            1 |                nan |             nan |         nan |            nan |               nan | b75df1bd-0f22d631-52d73526-2ae7b85a-d843b39d | postero-anterior | train   |     21880113 |             1 |
# |  7 |     10000935 |   50578979 |           nan |            nan |             nan |      -1 |                          nan |        nan |           nan |             -1 |          nan |                  1 |             nan |           1 |            nan |               nan | d0b71acc-b5a62046-bbb5f6b8-7b173b85-65cdf738 | antero-posterior | train   |     21871016 |             6 |
# |  8 |     10000935 |   51178377 |           nan |            nan |             nan |     nan |                          nan |        nan |           nan |              1 |          nan |                nan |             nan |          -1 |            nan |               nan | 9b314ad7-fbcb0422-6db62dfc-732858d0-a5527d8b | antero-posterior | train   |     21870823 |             4 |
# |  9 |     10000935 |   55697293 |           nan |            nan |             nan |     nan |                          nan |        nan |           nan |            nan |            1 |                nan |             nan |         nan |            nan |               nan | c50494f1-90e2bff5-e9189550-1a4562fd-6ab5204c | postero-anterior | train   |     21870226 |             2 |

# %%
metadata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227827 entries, 0 to 227826
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   subject_id                  227827 non-null  int64
#  1   study_id                    227827 non-null  int64
#  2   Atelectasis                 57666 non-null   float64
#  3   Cardiomegaly                66799 non-null   float64
#  4   Consolidation               23076 non-null   float64
#  5   Edema                       65833 non-null   float64
#  6   Enlarged Cardiomediastinum  21837 non-null   float64
#  7   Fracture                    5831 non-null    float64
#  8   Lung Lesion                 8287 non-null    float64
#  9   Lung Opacity                58425 non-null   float64
#  10  No Finding                  75455 non-null   float64
#  11  Pleural Effusion            87272 non-null   float64
#  12  Pleural Other               2902 non-null    float64
#  13  Pneumonia                   59185 non-null   float64
#  14  Pneumothorax                53848 non-null   float64
#  15  Support Devices             70281 non-null   float64
#  16  dicom_id                    227827 non-null  object
#  17  view                        218936 non-null  object
#  18  split                       227827 non-null  object
#  19  study_date                  227827 non-null  int64
#  20  study_order                 227827 non-null  float64
# dtypes: float64(15), int64(3), object(3)
# memory usage: 36.5+ MB

# %%
metadata_df['view'].unique()
# Out:
# array(['postero-anterior', 'antero-posterior', nan, 'Erect',
#        'left lateral', 'lateral', 'Recumbent', 'left anterior oblique'],
#       dtype=object)

# %%
label_columns = [
    'Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema',
    'Enlarged Cardiomediastinum', 'Fracture', 'Lung Lesion', 'Lung Opacity',
    'No Finding', 'Pleural Effusion', 'Pleural Other', 'Pneumonia',
    'Pneumothorax', 'Support Devices'
]

findings_prevalence = metadata_df[label_columns].apply(lambda x: (x == 1.0).sum())
findings_prevalence = findings_prevalence.sort_values(ascending=False)

# %%
plt.figure(figsize=(12,8))
sns.barplot(x=findings_prevalence.values, y=findings_prevalence.index, palette='plasma', orient='h', hue=findings_prevalence.index)
plt.title('Prevalance of Medical Findings (Positive Labels)')
plt.xlabel('Number of Studies')
plt.ylabel('Finding')
plt.tight_layout()
plt.savefig(os.path.join(figures_path,'findings_prevalence.png'))
plt.show()

# %%
print("--- Analysis of Medical Findings ---")
print("Prevalence of each finding (Positive Labels):\n")
print(findings_prevalence)
# Out:
# --- Analysis of Medical Findings ---
# Prevalence of each finding (Positive Labels):
#
# No Finding                    75455
# Support Devices               66558
# Pleural Effusion              54300
# Lung Opacity                  51525
# Atelectasis                   45808
# Cardiomegaly                  44845
# Edema                         27018
# Pneumonia                     16556
# Consolidation                 10778
# Pneumothorax                  10358
# Enlarged Cardiomediastinum     7179
# Lung Lesion                    6284
# Fracture                       4390
# Pleural Other                  2011
# dtype: int64

# %%
plt.figure(figsize=(7, 5))
ax = sns.countplot(x='view', data=metadata_df, palette='cubehelix', hue='view', legend=False)
ax.tick_params(axis='x', rotation=90)
plt.title('Distribution of Image Viewpoints')
plt.xlabel('View')
plt.ylabel('Count')
plt.savefig(os.path.join(figures_path,'viewpoint_distribution.png'))
plt.show()
